# %%
x = 3
# Out:
# ✅ **SAT** - Solution found:
#
# | Variable | Value |
# |----------|-------|
# | `x` | `3` |

# %%
y = x + 5
# Out:
# ✅ **SAT** - Solution found:
#
# | Variable | Value |
# |----------|-------|
# | `x` | `3` |
# | `y` | `8` |

# %%
z = x - 9
# Out:
# ❌ **Type Error:** z not found in scope.
